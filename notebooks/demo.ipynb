# %%
# Add relevant Jupyter notebook extensions

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\python311.zip', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\DLLs', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\Lib', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0', '', 'C:\\Users\\seanr\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages', 'C:\\Users\\seanr\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages\\win32', 'C:\\Users\\seanr\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages\\win32\\lib', 'C:\\Users\\seanr\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.1
# ...

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from uuv_mission import Submarine, ClosedLoop, Mission, PDController
sub = Submarine()
# Instantiate your controller (depending on your implementation)
A, B, C, D = sub.get_state_space()
controller = PDController(A, B, C, D)
closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv("C:/Users/seanr/B1 Scientific Coding/b1-coding-practical-mt24/data/mission.csv") # You must implement this method in the Mission class
random_mission = Mission.random_mission(duration=100, scale = 40)
trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Import relevant modules
# ----> 2 from uuv_mission import Submarine, ClosedLoop, Mission, PDController
#       3 sub = Submarine()
#       4 # Instantiate your controller (depending on your implementation)
#
# ModuleNotFoundError: No module named 'uuv_mission'
